# %%
import pandas as pd
print(f'Pandas {pd.__version__}')
import numpy as np
print(f'Numpy {np.__version__}')
import seaborn as sns
print(f'Seaborn {sns.__version__}')
import matplotlib
import matplotlib.pyplot as plt # for showing images
print('matplotlib: %s' % matplotlib.__version__) # print version
# !python --version
# Out:
# Pandas 1.3.5
# Numpy 1.19.5
# Seaborn 0.11.2
# matplotlib: 3.5.1
# Python 3.7.12

# %% [markdown]
# # Data download and Dataframe generation

# %%
from tabula import read_pdf 
from tabulate import tabulate

# %%
link = 'https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2019/barri1.pdf'
path ='C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\barri1.pdf'

df = read_pdf('barri1.pdf',pages=1)

# %%
import tabula
file = 'https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2019/barri1.pdf'

# convert PDF into CSV
tabula.convert_into(file, "iplmatch.csv", output_format="csv", pages='all')

# %% [markdown]
# # Download csv files

# %%
#Get a list with the url to download pdf files:
web_csvs = list(pd.read_csv('https://opendata-ajuntament.barcelona.cat/data/dataset/ef40b336-1b27-4ecf-9fc8-63af0347a7c0/resource/ed515bb8-502b-4dff-96dc-769f72767919/download/2019_divter.csv')['URL_FITXA_DIVISIO_TERRITORIAL'].iloc[:73])

# %% [markdown]
# Covert pdf files to csv directly:

# %%
barri_num =1
for i in web_csvs:
    nom = 'barri_'+str(barri_num)+'.csv'

    tabula.convert_into(i, nom, output_format="csv", pages='all')
    barri_num +=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\1596627879.py in <module>
#       3     nom = 'barri_'+str(barri_num)+'.csv'
#       4
# ----> 5     tabula.convert_into(i, nom, output_format="csv", pages='all')
#       6     barri_num +=1
#       7
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\tabula\io.py in convert_into(input_path, output_path, output_format, java_options, pages, guess, area, relative_area, lattice, stream, password, silent, columns, format, batch, options)
#     828
#     829     try:
# --> 830         _run(java_options, tabula_options, path)
#     831     finally:
#     832         if temporary:
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      90             stderr=subprocess.PIPE,
#      91             stdin=subprocess.DEVNULL,
# ---> 92             check=True,
#      93         )
#      94         if result.stderr:
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
# --> 490             stdout, stderr = process.communicate(input, timeout=timeout)
#     491         except TimeoutExpired as exc:
#     492             process.kill()
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\subprocess.py in communicate(self, input, timeout)
#     962
#     963             try:
# --> 964                 stdout, stderr = self._communicate(input, endtime, timeout)
#     965             except KeyboardInterrupt:
#     966                 # https://bugs.python.org/issue25942
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1294             # calls communicate again.
#    1295             if self.stdout is not None:
# -> 1296                 self.stdout_thread.join(self._remaining_time(endtime))
#    1297                 if self.stdout_thread.is_alive():
#    1298                     raise TimeoutExpired(self.args, orig_timeout)
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # Data Frame generation

# %%
def to_num(string):
    if ',' in string:
        num = string.split(',')
        num_tot = num[0]+'.'+ num[1]
    else:
        num_tot = string
    return float (num_tot)

# %%
lista_param = ["Nombre d'aturats registrats (5)", 
                'Renda familiar disponible per habitant (2017)',
                "Nombre d'aturats registrats (5)", 
                '65 i mes', 'Superfície (km2)',
                'Densitat (hab/km2)',
                'Taxa natalitat / 1.000 hab.',
                'Població de més de 65 anys que viu sola (%) (2)',
                'Índex de sobreenvelliment  (3)']

lista_param_correct = ["Nombre d'aturats registrats (5)", 
            'Renda familiar disponible per habitant (2017)', 
            "Nombre d'aturats registrats (5)", 
            '65 i mes', 
            'SuperfÃ\xadcie (km2)',
            'Densitat (hab/km2)',
            'Taxa natalitat / 1.000 hab.',
            'PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)',
            'Ã\x8dndex de sobreenvelliment  (3)']

# %%
total_df=pd.DataFrame()
for z in range(1,16):
    
    file = 'barri_'+str(z)+'.csv'
    path_file ="C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\" + file
    df=pd.read_csv (path_file , encoding = 'ISO-8859-1') 
    df_new =pd.DataFrame()
    
    for i in lista_param_correct:
        print (z,'  ---->', i)
        #print (df[df.iloc[:,0] == i].iloc[:,0])
        i_barrio = i +'_barrio'
        i_distrito = i +'_districte' 
        #i_BCN = i +'_BCN'
        columna1 =df.columns[1]
        columna2 =df.columns[2]
        df_new [i_barrio] = [df[df.iloc[:,0] == i][columna1].iloc[0]]
        df_new [i_distrito] = [df[df.iloc[:,0] == i][columna2].iloc[0]]
        #df_new [i_BCN] = [df[df.iloc[:,0] == i]['BARCELONA'].iloc[0]]
        df_new ['num_barrio']= z
    total_df = pd.concat([total_df, df_new])
# Out:
# 1   ----> Nombre d'aturats registrats (5)
# 1   ----> Renda familiar disponible per habitant (2017)
# 1   ----> Nombre d'aturats registrats (5)
# 1   ----> 65 i mes
# 1   ----> SuperfÃ­cie (km2)
# 1   ----> Densitat (hab/km2)
# 1   ----> Taxa natalitat / 1.000 hab.
# 1   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 1   ----> Ãndex de sobreenvelliment  (3)
# 2   ----> Nombre d'aturats registrats (5)
# 2   ----> Renda familiar disponible per habitant (2017)
# 2   ----> Nombre d'aturats registrats (5)
# 2   ----> 65 i mes
# 2   ----> SuperfÃ­cie (km2)
# 2   ----> Densitat (hab/km2)
# 2   ----> Taxa natalitat / 1.000 hab.
# 2   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 2   ----> Ãndex de sobreenvelliment  (3)
# 3   ----> Nombre d'aturats registrats (5)
# 3   ----> Renda familiar disponible per habitant (2017)
# 3   ----> Nombre d'aturats registrats (5)
# 3   ----> 65 i mes
# 3   ----> SuperfÃ­cie (km2)
# 3   ----> Densitat (hab/km2)
# 3   ----> Taxa natalitat / 1.000 hab.
# 3   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 3   ----> Ãndex de sobreenvelliment  (3)
# 4   ----> Nombre d'aturats registrats (5)
# 4   ----> Renda familiar disponible per habitant (2017)
# 4   ----> Nombre d'aturats registrats (5)
# 4   ----> 65 i mes
# 4   ----> SuperfÃ­cie (km2)
# 4   ----> Densitat (hab/km2)
# 4   ----> Taxa natalitat / 1.000 hab.
# 4   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 4   ----> Ãndex de sobreenvelliment  (3)
# 5   ----> Nombre d'aturats registrats (5)
# 5   ----> Renda familiar disponible per habitant (2017)
# 5   ----> Nombre d'aturats registrats (5)
# 5   ----> 65 i mes
# 5   ----> SuperfÃ­cie (km2)
# 5   ----> Densitat (hab/km2)
# 5   ----> Taxa natalitat / 1.000 hab.
# 5   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 5   ----> Ãndex de sobreenvelliment  (3)
# 6   ----> Nombre d'aturats registrats (5)
# 6   ----> Renda familiar disponible per habitant (2017)
# 6   ----> Nombre d'aturats registrats (5)
# 6   ----> 65 i mes
# 6   ----> SuperfÃ­cie (km2)
# 6   ----> Densitat (hab/km2)
# 6   ----> Taxa natalitat / 1.000 hab.
# 6   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 6   ----> Ãndex de sobreenvelliment  (3)
# 7   ----> Nombre d'aturats registrats (5)
# 7   ----> Renda familiar disponible per habitant (2017)
# 7   ----> Nombre d'aturats registrats (5)
# 7   ----> 65 i mes
# 7   ----> SuperfÃ­cie (km2)
# 7   ----> Densitat (hab/km2)
# 7   ----> Taxa natalitat / 1.000 hab.
# 7   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 7   ----> Ãndex de sobreenvelliment  (3)
# 8   ----> Nombre d'aturats registrats (5)
# 8   ----> Renda familiar disponible per habitant (2017)
# 8   ----> Nombre d'aturats registrats (5)
# 8   ----> 65 i mes
# 8   ----> SuperfÃ­cie (km2)
# 8   ----> Densitat (hab/km2)
# 8   ----> Taxa natalitat / 1.000 hab.
# 8   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 8   ----> Ãndex de sobreenvelliment  (3)
# 9   ----> Nombre d'aturats registrats (5)
# 9   ----> Renda familiar disponible per habitant (2017)
# 9   ----> Nombre d'aturats registrats (5)
# 9   ----> 65 i mes
# 9   ----> SuperfÃ­cie (km2)
# 9   ----> Densitat (hab/km2)
# 9   ----> Taxa natalitat / 1.000 hab.
# 9   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 9   ----> Ãndex de sobreenvelliment  (3)
# 10   ----> Nombre d'aturats registrats (5)
# 10   ----> Renda familiar disponible per habitant (2017)
# 10   ----> Nombre d'aturats registrats (5)
# 10   ----> 65 i mes
# 10   ----> SuperfÃ­cie (km2)
# 10   ----> Densitat (hab/km2)
# 10   ----> Taxa natalitat / 1.000 hab.
# 10   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 10   ----> Ãndex de sobreenvelliment  (3)
# 11   ----> Nombre d'aturats registrats (5)
# 11   ----> Renda familiar disponible per habitant (2017)
# 11   ----> Nombre d'aturats registrats (5)
# 11   ----> 65 i mes
# 11   ----> SuperfÃ­cie (km2)
# 11   ----> Densitat (hab/km2)
# 11   ----> Taxa natalitat / 1.000 hab.
# 11   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 11   ----> Ãndex de sobreenvelliment  (3)
# 12   ----> Nombre d'aturats registrats (5)
# 12   ----> Renda familiar disponible per habitant (2017)
# 12   ----> Nombre d'aturats registrats (5)
# 12   ----> 65 i mes
# 12   ----> SuperfÃ­cie (km2)
# 12   ----> Densitat (hab/km2)
# 12   ----> Taxa natalitat / 1.000 hab.
# 12   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 12   ----> Ãndex de sobreenvelliment  (3)
# 13   ----> Nombre d'aturats registrats (5)
# 13   ----> Renda familiar disponible per habitant (2017)
# 13   ----> Nombre d'aturats registrats (5)
# 13   ----> 65 i mes
# 13   ----> SuperfÃ­cie (km2)
# 13   ----> Densitat (hab/km2)
# 13   ----> Taxa natalitat / 1.000 hab.
# 13   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 13   ----> Ãndex de sobreenvelliment  (3)
# 14   ----> Nombre d'aturats registrats (5)
# 14   ----> Renda familiar disponible per habitant (2017)
# 14   ----> Nombre d'aturats registrats (5)
# 14   ----> 65 i mes
# 14   ----> SuperfÃ­cie (km2)
# 14   ----> Densitat (hab/km2)
# 14   ----> Taxa natalitat / 1.000 hab.
# 14   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 14   ----> Ãndex de sobreenvelliment  (3)
# 15   ----> Nombre d'aturats registrats (5)
# 15   ----> Renda familiar disponible per habitant (2017)
# 15   ----> Nombre d'aturats registrats (5)
# 15   ----> 65 i mes
# 15   ----> SuperfÃ­cie (km2)
# 15   ----> Densitat (hab/km2)
# 15   ----> Taxa natalitat / 1.000 hab.
# 15   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 15   ----> Ãndex de sobreenvelliment  (3)

# %%
total_df
# Out:
#   Nombre d'aturats registrats (5)_barrio  \
# 0                                  3.074
# 0                                    892
# 0                                    978
# 0                                  1.346
# 0                                  1.156
# 0                                  1.917
# 0                                  1.255
# 0                                  1.345
# 0                                  2.117
# 0                                  1.535
# 0                                  2.045
# 0                                     93
# 0                                  1.548
# 0                                    516
# 0                                    684
#
#   Nombre d'aturats registrats (5)_districte  num_barrio  \
# 0                                     6.290           1
# 0                                     6.290           2
# 0                                     6.290           3
# 0                                     6.290           4
# 0                                     9.326           5
# 0                                     9.326           6
# 0                                     9.326           7
# 0                                     9.326           8
# 0                                     9.326           9
# 0                                     9.326          10
# 0                                     8.162          11
# 0                                     8.162          12
# 0                                     8.162          13
# 0                                     8.162          14
# 0                                     8.162          15
#
#   Renda familiar disponible per habitant (2017)_barrio  \
# 0                                               71,2
# 0                                              106,1
# 0                                               79,6
# 0                                               99,4
# 0                                              106,5
# 0                                              101,8
# 0                                              175,9
# 0                                              137,2
# 0                                              110,2
# 0                                              104,2
# 0                                               82,2
# 0                                               40,0
# 0                                               69,3
# 0                                               82,9
# 0                                               99,0
#
#   Renda familiar disponible per habitant (2017)_districte 65 i mes_barrio  \
# 0                                               84,3                 11,3
# 0                                               84,3                 10,1
# 0                                               84,3                 17,0
# 0                                               84,3                 13,6
# 0                                              122,4                 20,8
# 0                                              122,4                 22,2
# 0                                              122,4                 21,3
# 0                                              122,4                 20,8
# 0                                              122,4                 23,4
# 0                                              122,4                 22,0
# 0                                               84,6                 16,6
# 0                                               84,6                 18,1
# 0                                               84,6                 19,9
# 0                                               84,6                 23,5
# 0                                               84,6                 19,2
#
#   65 i mes_districte SuperfÃ­cie (km2)_barrio SuperfÃ­cie (km2)_districte  \
# 0               12,3                      1,1                         4,1
# 0               12,3                      0,8                         4,1
# 0               12,3                      1,1                         4,1
# 0               12,3                      1,1                         4,1
# 0               21,9                      0,9                         7,5
# 0               21,9                      1,0                         7,5
# 0               21,9                      2,1                         7,5
# 0               21,9                      1,2                         7,5
# 0               21,9                      1,3                         7,5
# 0               21,9                      0,8                         7,5
# 0               19,9                      4,6                        22,7
# 0               19,9                     14,0                        22,7
# 0               19,9                      1,3                        22,7
# 0               19,9                      0,3                        22,7
# 0               19,9                      0,4                        22,7
#
#   Densitat (hab/km2)_barrio Densitat (hab/km2)_districte  \
# 0                    43.864                       26.288
# 0                    26.625                       26.288
# 0                    13.795                       26.288
# 0                    20.944                       26.288
# 0                    35.906                       36.265
# 0                    50.147                       36.265
# 0                    20.909                       36.265
# 0                    35.189                       36.265
# 0                    43.724                       36.265
# 0                    48.384                       36.265
# 0                     8.758                        8.272
# 0                        87                        8.272
# 0                    24.714                        8.272
# 0                    34.931                        8.272
# 0                    39.527                        8.272
#
#   Taxa natalitat / 1.000 hab._barrio Taxa natalitat / 1.000 hab._districte  \
# 0                                9,1                                   7,6
# 0                                6,7                                   7,6
# 0                                5,7                                   7,6
# 0                                6,3                                   7,6
# 0                                6,3                                   7,2
# 0                                7,0                                   7,2
# 0                                7,7                                   7,2
# 0                                7,2                                   7,2
# 0                                7,4                                   7,2
# 0                                7,6                                   7,2
# 0                                7,3                                   8,0
# 0                               10,9                                   8,0
# 0                                8,0                                   8,0
# 0                                6,7                                   8,0
# 0                                7,5                                   8,0
#
#   PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio  \
# 0                                               31,9
# 0                                               30,2
# 0                                               32,8
# 0                                               33,6
# 0                                               25,3
# 0                                               27,5
# 0                                               27,1
# 0                                               29,0
# 0                                               26,8
# 0                                               28,5
# 0                                               28,6
# 0                                               31,5
# 0                                               25,4
# 0                                               24,9
# 0                                               24,7
#
#   PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_districte  \
# 0                                               32,2
# 0                                               32,2
# 0                                               32,2
# 0                                               32,2
# 0                                               27,4
# 0                                               27,4
# 0                                               27,4
# 0                                               27,4
# 0                                               27,4
# 0                                               27,4
# 0                                               25,7
# 0                                               25,7
# 0                                               25,7
# 0                                               25,7
# 0                                               25,7
#
#   Ãndex de sobreenvelliment  (3)_barrio  \
# 0                                   50,7
# 0                                   50,2
# 0                                   58,1
# 0                                   53,2
# 0                                   52,3
# 0                                   53,5
# 0                                   54,0
# 0                                   54,4
# 0                                   51,6
# 0                                   56,4
# 0                                   53,7
# 0                                   53,2
# 0                                   53,8
# 0                                   51,9
# 0                                   48,9
#
#   Ãndex de sobreenvelliment  (3)_districte
# 0                                      52,6
# 0                                      52,6
# 0                                      52,6
# 0                                      52,6
# 0                                      53,5
# 0                                      53,5
# 0                                      53,5
# 0                                      53,5
# 0                                      53,5
# 0                                      53,5
# 0                                      52,2
# 0                                      52,2
# 0                                      52,2
# 0                                      52,2
# 0                                      52,2

# %%
for z in range(17,47):
    
    file = 'barri_'+str(z)+'.csv'
    path_file ="C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\" + file
    df=pd.read_csv (path_file , encoding = 'ISO-8859-1') 
    #print(df)
    df_new =pd.DataFrame()
    
    for i in lista_param_correct:
        #print (z,'  ---->', i)
        #print (df[df.iloc[:,0] == i].iloc[:,0])
        i_barrio = i +'_barrio'
        i_distrito = i +'_districte' 
        #i_BCN = i +'_BCN'
        columna1 =df.columns[1]
        columna2 =df.columns[2]
        df_new [i_barrio] = [df[df.iloc[:,0] == i][columna1].iloc[0]]
        df_new [i_distrito] = [df[df.iloc[:,0] == i][columna2].iloc[0]]
        #df_new [i_BCN] = [df[df.iloc[:,0] == i]['BARCELONA'].iloc[0]]
        df_new ['num_barrio']= z
    total_df = pd.concat([total_df, df_new])

# %%
for z in range(48,67):
    
    file = 'barri_'+str(z)+'.csv'
    path_file ="C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\" + file
    df=pd.read_csv (path_file , encoding = 'ISO-8859-1') 
    print(df)
    df_new =pd.DataFrame()
    
    for i in lista_param_correct:
        print (z,'  ---->', i)
        #print (df[df.iloc[:,0] == i].iloc[:,0])
        i_barrio = i +'_barrio'
        i_distrito = i +'_districte' 
        #i_BCN = i +'_BCN'
        columna1 =df.columns[1]
        columna2 =df.columns[2]
        df_new [i_barrio] = [df[df.iloc[:,0] == i][columna1].iloc[0]]
        df_new [i_distrito] = [df[df.iloc[:,0] == i][columna1].iloc[0]]
        #df_new [i_BCN] = [df[df.iloc[:,0] == i]['BARCELONA'].iloc[0]]
        df_new ['num_barrio']= z
    total_df = pd.concat([total_df, df_new])
# Out:
#                       INDICADORS SOCIOECONÃMICS 2019      BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³     15.420     174.012
# 1                                   SuperfÃ­cie (km2)        0,6         8,1
# 2                                  Densitat (hab/km2)     25.198      21.614
# 3                                  PoblaciÃ³ per sexe        NaN         NaN
# 4                                               Dones      8.303      92.318
# 5                                               Homes      7.117      81.694
# 6                           PoblaciÃ³ per edat (en %)        NaN         NaN
# 7                                                0-14       12,1        13,1
# 8                                               15-24        9,1         9,8
# 9                                               25-64       50,5        54,7
# 10                                           65 i mes       28,2        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)        NaN         NaN
# 12                                          Barcelona       54,1        46,4
# 13                                    Resta Catalunya        5,7         4,8
# 14                                      Resta Espanya       24,3        20,9
# 15                                          Estranger       15,9        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)        NaN         NaN
# 17                                          Espanyols       89,3        79,7
# 18                                         Estrangers       10,7        20,3
# 19               Principals nacionalitats estrangeres        NaN         NaN
# 20                                                NaN   Hondures    Hondures
# 21                                                NaN        226       5.548
# 22                                                NaN  ColÃ²mbia    Pakistan
# 23                                                NaN        114       2.517
# 24                                                NaN      PerÃº  Marroc, el
# 25                                                NaN        105       2.123
# 26                    % Titulats superiors i CFGS (1)       19,0        15,5
# 27                        Taxa natalitat / 1.000 hab.        6,8         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)       24,5        25,7
# 29                    Ãndex de sobreenvelliment  (3)       57,3        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)      302,5       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)       92,6        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)       19,1        22,7
# 33                    Nombre d'aturats registrats (5)        857       9.297
# 34      Renda familiar disponible per habitant (2017)       53,8        55,0
# 35                               Ãndex Barcelona=100        NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 48   ----> Nombre d'aturats registrats (5)
# 48   ----> Renda familiar disponible per habitant (2017)
# 48   ----> Nombre d'aturats registrats (5)
# 48   ----> 65 i mes
# 48   ----> SuperfÃ­cie (km2)
# 48   ----> Densitat (hab/km2)
# 48   ----> Taxa natalitat / 1.000 hab.
# 48   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 48   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019     BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³     6.869     174.012
# 1                                   SuperfÃ­cie (km2)       0,8         8,1
# 2                                  Densitat (hab/km2)     8.694      21.614
# 3                                  PoblaciÃ³ per sexe       NaN         NaN
# 4                                               Dones     3.620      92.318
# 5                                               Homes     3.249      81.694
# 6                           PoblaciÃ³ per edat (en %)       NaN         NaN
# 7                                                0-14      10,8        13,1
# 8                                               15-24       8,8         9,8
# 9                                               25-64      51,4        54,7
# 10                                           65 i mes      28,9        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)       NaN         NaN
# 12                                          Barcelona      56,1        46,4
# 13                                    Resta Catalunya       4,8         4,8
# 14                                      Resta Espanya      28,8        20,9
# 15                                          Estranger      10,2        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)       NaN         NaN
# 17                                          Espanyols      93,3        79,7
# 18                                         Estrangers       6,7        20,3
# 19               Principals nacionalitats estrangeres       NaN         NaN
# 20                                                NaN  Hondures    Hondures
# 21                                                NaN        55       5.548
# 22                                                NaN     PerÃº    Pakistan
# 23                                                NaN        36       2.517
# 24                                                NaN   Equador  Marroc, el
# 25                                                NaN        27       2.123
# 26                    % Titulats superiors i CFGS (1)      13,2        15,5
# 27                        Taxa natalitat / 1.000 hab.       5,2         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)      21,3        25,7
# 29                    Ãndex de sobreenvelliment  (3)      45,8        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)     381,3       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)      98,7        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)      29,3        22,7
# 33                    Nombre d'aturats registrats (5)       418       9.297
# 34      Renda familiar disponible per habitant (2017)      52,2        55,0
# 35                               Ãndex Barcelona=100       NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 49   ----> Nombre d'aturats registrats (5)
# 49   ----> Renda familiar disponible per habitant (2017)
# 49   ----> Nombre d'aturats registrats (5)
# 49   ----> 65 i mes
# 49   ----> SuperfÃ­cie (km2)
# 49   ----> Densitat (hab/km2)
# 49   ----> Taxa natalitat / 1.000 hab.
# 49   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 49   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³      16.417     174.012
# 1                                   SuperfÃ­cie (km2)         0,6         8,1
# 2                                  Densitat (hab/km2)      25.531      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones       8.516      92.318
# 5                                               Homes       7.901      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        15,0        13,1
# 8                                               15-24        10,9         9,8
# 9                                               25-64        56,6        54,7
# 10                                           65 i mes        17,5        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        44,4        46,4
# 13                                    Resta Catalunya         3,6         4,8
# 14                                      Resta Espanya        20,0        20,9
# 15                                          Estranger        32,0        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        75,3        79,7
# 18                                         Estrangers        24,7        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN    Hondures    Hondures
# 21                                                NaN       1.076       5.548
# 22                                                NaN    Pakistan    Pakistan
# 23                                                NaN         286       2.517
# 24                                                NaN  Marroc, el  Marroc, el
# 25                                                NaN         241       2.123
# 26                    % Titulats superiors i CFGS (1)         9,8        15,5
# 27                        Taxa natalitat / 1.000 hab.         9,0         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        23,4        25,7
# 29                    Ãndex de sobreenvelliment  (3)        50,4        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       269,5       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        77,4        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        25,8        22,7
# 33                    Nombre d'aturats registrats (5)         906       9.297
# 34      Renda familiar disponible per habitant (2017)        49,7        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 50   ----> Nombre d'aturats registrats (5)
# 50   ----> Renda familiar disponible per habitant (2017)
# 50   ----> Nombre d'aturats registrats (5)
# 50   ----> 65 i mes
# 50   ----> SuperfÃ­cie (km2)
# 50   ----> Densitat (hab/km2)
# 50   ----> Taxa natalitat / 1.000 hab.
# 50   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 50   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³      12.798     174.012
# 1                                   SuperfÃ­cie (km2)         0,2         8,1
# 2                                  Densitat (hab/km2)      53.973      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones       6.832      92.318
# 5                                               Homes       5.966      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        13,2        13,1
# 8                                               15-24         9,9         9,8
# 9                                               25-64        56,0        54,7
# 10                                           65 i mes        20,9        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        43,5        46,4
# 13                                    Resta Catalunya         4,0         4,8
# 14                                      Resta Espanya        21,6        20,9
# 15                                          Estranger        30,9        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        76,8        79,7
# 18                                         Estrangers        23,2        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN    Hondures    Hondures
# 21                                                NaN         621       5.548
# 22                                                NaN        Xina    Pakistan
# 23                                                NaN         172       2.517
# 24                                                NaN  Marroc, el  Marroc, el
# 25                                                NaN         155       2.123
# 26                    % Titulats superiors i CFGS (1)        12,9        15,5
# 27                        Taxa natalitat / 1.000 hab.         7,7         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        28,2        25,7
# 29                    Ãndex de sobreenvelliment  (3)        58,0        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       244,2       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        73,1        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        22,7        22,7
# 33                    Nombre d'aturats registrats (5)         695       9.297
# 34      Renda familiar disponible per habitant (2017)        51,3        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 51   ----> Nombre d'aturats registrats (5)
# 51   ----> Renda familiar disponible per habitant (2017)
# 51   ----> Nombre d'aturats registrats (5)
# 51   ----> 65 i mes
# 51   ----> SuperfÃ­cie (km2)
# 51   ----> Densitat (hab/km2)
# 51   ----> Taxa natalitat / 1.000 hab.
# 51   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 51   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019     BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³    27.003     174.012
# 1                                   SuperfÃ­cie (km2)       0,6         8,1
# 2                                  Densitat (hab/km2)    45.673      21.614
# 3                                  PoblaciÃ³ per sexe       NaN         NaN
# 4                                               Dones    14.357      92.318
# 5                                               Homes    12.646      81.694
# 6                           PoblaciÃ³ per edat (en %)       NaN         NaN
# 7                                                0-14      12,3        13,1
# 8                                               15-24       9,4         9,8
# 9                                               25-64      53,7        54,7
# 10                                           65 i mes      24,6        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)       NaN         NaN
# 12                                          Barcelona      45,5        46,4
# 13                                    Resta Catalunya       4,8         4,8
# 14                                      Resta Espanya      25,0        20,9
# 15                                          Estranger      24,7        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)       NaN         NaN
# 17                                          Espanyols      82,4        79,7
# 18                                         Estrangers      17,6        20,3
# 19               Principals nacionalitats estrangeres       NaN         NaN
# 20                                                NaN  Hondures    Hondures
# 21                                                NaN       800       5.548
# 22                                                NaN      Xina    Pakistan
# 23                                                NaN       355       2.517
# 24                                                NaN     PerÃº  Marroc, el
# 25                                                NaN       274       2.123
# 26                    % Titulats superiors i CFGS (1)      13,2        15,5
# 27                        Taxa natalitat / 1.000 hab.       7,1         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)      25,6        25,7
# 29                    Ãndex de sobreenvelliment  (3)      58,0        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)     271,8       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)      81,9        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)      20,7        22,7
# 33                    Nombre d'aturats registrats (5)     1.347       9.297
# 34      Renda familiar disponible per habitant (2017)      56,0        55,0
# 35                               Ãndex Barcelona=100       NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 52   ----> Nombre d'aturats registrats (5)
# 52   ----> Renda familiar disponible per habitant (2017)
# 52   ----> Nombre d'aturats registrats (5)
# 52   ----> 65 i mes
# 52   ----> SuperfÃ­cie (km2)
# 52   ----> Densitat (hab/km2)
# 52   ----> Taxa natalitat / 1.000 hab.
# 52   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 52   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³       7.669     174.012
# 1                                   SuperfÃ­cie (km2)         0,6         8,1
# 2                                  Densitat (hab/km2)      13.298      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones       4.017      92.318
# 5                                               Homes       3.652      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        14,1        13,1
# 8                                               15-24        11,0         9,8
# 9                                               25-64        57,6        54,7
# 10                                           65 i mes        17,3        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        49,2        46,4
# 13                                    Resta Catalunya         4,3         4,8
# 14                                      Resta Espanya        14,3        20,9
# 15                                          Estranger        32,2        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        75,5        79,7
# 18                                         Estrangers        24,5        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN    Hondures    Hondures
# 21                                                NaN         220       5.548
# 22                                                NaN    Pakistan    Pakistan
# 23                                                NaN         206       2.517
# 24                                                NaN  Marroc, el  Marroc, el
# 25                                                NaN         136       2.123
# 26                    % Titulats superiors i CFGS (1)         9,6        15,5
# 27                        Taxa natalitat / 1.000 hab.         8,2         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        31,4        25,7
# 29                    Ãndex de sobreenvelliment  (3)        52,9        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       241,2       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        67,2        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        29,6        22,7
# 33                    Nombre d'aturats registrats (5)         620       9.297
# 34      Renda familiar disponible per habitant (2017)        48,2        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 53   ----> Nombre d'aturats registrats (5)
# 53   ----> Renda familiar disponible per habitant (2017)
# 53   ----> Nombre d'aturats registrats (5)
# 53   ----> 65 i mes
# 53   ----> SuperfÃ­cie (km2)
# 53   ----> Densitat (hab/km2)
# 53   ----> Taxa natalitat / 1.000 hab.
# 53   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 53   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³       2.925     174.012
# 1                                   SuperfÃ­cie (km2)         1,7         8,1
# 2                                  Densitat (hab/km2)       1.679      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones       1.467      92.318
# 5                                               Homes       1.458      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        17,7        13,1
# 8                                               15-24        12,6         9,8
# 9                                               25-64        56,3        54,7
# 10                                           65 i mes        13,3        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        49,3        46,4
# 13                                    Resta Catalunya         5,8         4,8
# 14                                      Resta Espanya        17,3        20,9
# 15                                          Estranger        27,6        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        80,3        79,7
# 18                                         Estrangers        19,7        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN  Marroc, el    Hondures
# 21                                                NaN         141       5.548
# 22                                                NaN    Hondures    Pakistan
# 23                                                NaN          63       2.517
# 24                                                NaN    Pakistan  Marroc, el
# 25                                                NaN          30       2.123
# 26                    % Titulats superiors i CFGS (1)         8,9        15,5
# 27                        Taxa natalitat / 1.000 hab.        10,0         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        21,3        25,7
# 29                    Ãndex de sobreenvelliment  (3)        44,9        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       295,7       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        78,3        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        44,8        22,7
# 33                    Nombre d'aturats registrats (5)         172       9.297
# 34      Renda familiar disponible per habitant (2017)        46,5        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 54   ----> Nombre d'aturats registrats (5)
# 54   ----> Renda familiar disponible per habitant (2017)
# 54   ----> Nombre d'aturats registrats (5)
# 54   ----> 65 i mes
# 54   ----> SuperfÃ­cie (km2)
# 54   ----> Densitat (hab/km2)
# 54   ----> Taxa natalitat / 1.000 hab.
# 54   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 54   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³      11.091     174.012
# 1                                   SuperfÃ­cie (km2)         0,4         8,1
# 2                                  Densitat (hab/km2)      29.444      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones       5.675      92.318
# 5                                               Homes       5.416      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        17,3        13,1
# 8                                               15-24        11,9         9,8
# 9                                               25-64        54,1        54,7
# 10                                           65 i mes        16,7        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        35,3        46,4
# 13                                    Resta Catalunya         3,8         4,8
# 14                                      Resta Espanya        18,0        20,9
# 15                                          Estranger        42,9        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        67,2        79,7
# 18                                         Estrangers        32,8        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN    Hondures    Hondures
# 21                                                NaN         689       5.548
# 22                                                NaN    Pakistan    Pakistan
# 23                                                NaN         527       2.517
# 24                                                NaN  Marroc, el  Marroc, el
# 25                                                NaN         441       2.123
# 26                    % Titulats superiors i CFGS (1)         7,4        15,5
# 27                        Taxa natalitat / 1.000 hab.        13,4         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        22,3        25,7
# 29                    Ãndex de sobreenvelliment  (3)        53,4        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       240,9       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        42,3        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        19,7        22,7
# 33                    Nombre d'aturats registrats (5)         896       9.297
# 34      Renda familiar disponible per habitant (2017)        38,6        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 55   ----> Nombre d'aturats registrats (5)
# 55   ----> Renda familiar disponible per habitant (2017)
# 55   ----> Nombre d'aturats registrats (5)
# 55   ----> 65 i mes
# 55   ----> SuperfÃ­cie (km2)
# 55   ----> Densitat (hab/km2)
# 55   ----> Taxa natalitat / 1.000 hab.
# 55   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 55   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI   DISTRICTE  \
# 0                                           PoblaciÃ³       1.421     174.012
# 1                                   SuperfÃ­cie (km2)         0,6         8,1
# 2                                  Densitat (hab/km2)       2.336      21.614
# 3                                  PoblaciÃ³ per sexe         NaN         NaN
# 4                                               Dones         735      92.318
# 5                                               Homes         686      81.694
# 6                           PoblaciÃ³ per edat (en %)         NaN         NaN
# 7                                                0-14        17,7        13,1
# 8                                               15-24        10,1         9,8
# 9                                               25-64        54,5        54,7
# 10                                           65 i mes        17,7        22,3
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN         NaN
# 12                                          Barcelona        49,5        46,4
# 13                                    Resta Catalunya         6,8         4,8
# 14                                      Resta Espanya        20,0        20,9
# 15                                          Estranger        23,8        27,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN         NaN
# 17                                          Espanyols        83,9        79,7
# 18                                         Estrangers        16,1        20,3
# 19               Principals nacionalitats estrangeres         NaN         NaN
# 20                                                NaN    Pakistan    Hondures
# 21                                                NaN          49       5.548
# 22                                                NaN  Marroc, el    Pakistan
# 23                                                NaN          31       2.517
# 24                                                NaN    Hondures  Marroc, el
# 25                                                NaN          15       2.123
# 26                    % Titulats superiors i CFGS (1)         9,5        15,5
# 27                        Taxa natalitat / 1.000 hab.         8,5         7,9
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        13,9        25,7
# 29                    Ãndex de sobreenvelliment  (3)        59,4        56,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       308,2       259,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        85,2        79,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        44,3        22,7
# 33                    Nombre d'aturats registrats (5)         104       9.297
# 34      Renda familiar disponible per habitant (2017)        40,9        55,0
# 35                               Ãndex Barcelona=100         NaN         NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 56   ----> Nombre d'aturats registrats (5)
# 56   ----> Renda familiar disponible per habitant (2017)
# 56   ----> Nombre d'aturats registrats (5)
# 56   ----> 65 i mes
# 56   ----> SuperfÃ­cie (km2)
# 56   ----> Densitat (hab/km2)
# 56   ----> Taxa natalitat / 1.000 hab.
# 56   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 56   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³      10.487   151.976
# 1                                   SuperfÃ­cie (km2)         0,8       6,6
# 2                                  Densitat (hab/km2)      12.986    23.065
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones       5.143    79.738
# 5                                               Homes       5.344    72.238
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        17,2      13,2
# 8                                               15-24        11,2       9,1
# 9                                               25-64        56,6      56,0
# 10                                           65 i mes        15,0      21,7
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        39,2      53,9
# 13                                    Resta Catalunya         4,0       6,9
# 14                                      Resta Espanya        16,6      17,7
# 15                                          Estranger        40,1      21,5
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        67,8      84,8
# 18                                         Estrangers        32,2      15,2
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN    Pakistan      Xina
# 21                                                NaN         799     2.129
# 22                                                NaN  Marroc, el  Pakistan
# 23                                                NaN         591     1.710
# 24                                                NaN     Equador   ItÃ lia
# 25                                                NaN         161     1.675
# 26                    % Titulats superiors i CFGS (1)        10,4      24,4
# 27                        Taxa natalitat / 1.000 hab.        11,3       7,8
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        22,4      24,0
# 29                    Ãndex de sobreenvelliment  (3)        49,0      50,2
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       254,6     280,2
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        63,9      93,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        27,8      20,7
# 33                    Nombre d'aturats registrats (5)         831     6.828
# 34      Renda familiar disponible per habitant (2017)        47,1      74,6
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 57   ----> Nombre d'aturats registrats (5)
# 57   ----> Renda familiar disponible per habitant (2017)
# 57   ----> Nombre d'aturats registrats (5)
# 57   ----> 65 i mes
# 57   ----> SuperfÃ­cie (km2)
# 57   ----> Densitat (hab/km2)
# 57   ----> Taxa natalitat / 1.000 hab.
# 57   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 57   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³       2.625   151.976
# 1                                   SuperfÃ­cie (km2)         0,2       6,6
# 2                                  Densitat (hab/km2)      11.418    23.065
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones       1.346    79.738
# 5                                               Homes       1.279    72.238
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        16,2      13,2
# 8                                               15-24        10,4       9,1
# 9                                               25-64        57,4      56,0
# 10                                           65 i mes        16,0      21,7
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        57,4      53,9
# 13                                    Resta Catalunya         9,6       6,9
# 14                                      Resta Espanya        12,3      17,7
# 15                                          Estranger        20,7      21,5
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        85,1      84,8
# 18                                         Estrangers        14,9      15,2
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN  Marroc, el      Xina
# 21                                                NaN          73     2.129
# 22                                                NaN    AlgÃ¨ria  Pakistan
# 23                                                NaN          37     1.710
# 24                                                NaN    Hondures   ItÃ lia
# 25                                                NaN          34     1.675
# 26                    % Titulats superiors i CFGS (1)         7,1      24,4
# 27                        Taxa natalitat / 1.000 hab.         8,5       7,8
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        28,0      24,0
# 29                    Ãndex de sobreenvelliment  (3)        52,3      50,2
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       270,9     280,2
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        74,7      93,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        26,7      20,7
# 33                    Nombre d'aturats registrats (5)         114     6.828
# 34      Renda familiar disponible per habitant (2017)        68,9      74,6
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 58   ----> Nombre d'aturats registrats (5)
# 58   ----> Renda familiar disponible per habitant (2017)
# 58   ----> Nombre d'aturats registrats (5)
# 58   ----> 65 i mes
# 58   ----> SuperfÃ­cie (km2)
# 58   ----> Densitat (hab/km2)
# 58   ----> Taxa natalitat / 1.000 hab.
# 58   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 58   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³      13.652   151.976
# 1                                   SuperfÃ­cie (km2)         1,9       6,6
# 2                                  Densitat (hab/km2)       7.321    23.065
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones       6.833    79.738
# 5                                               Homes       6.819    72.238
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        16,6      13,2
# 8                                               15-24        10,6       9,1
# 9                                               25-64        56,5      56,0
# 10                                           65 i mes        16,3      21,7
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        51,8      53,9
# 13                                    Resta Catalunya         7,2       6,9
# 14                                      Resta Espanya        14,2      17,7
# 15                                          Estranger        26,7      21,5
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        79,1      84,8
# 18                                         Estrangers        20,9      15,2
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN    Pakistan      Xina
# 21                                                NaN         427     2.129
# 22                                                NaN    Hondures  Pakistan
# 23                                                NaN         347     1.710
# 24                                                NaN  Marroc, el   ItÃ lia
# 25                                                NaN         218     1.675
# 26                    % Titulats superiors i CFGS (1)        14,3      24,4
# 27                        Taxa natalitat / 1.000 hab.         8,3       7,8
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        22,7      24,0
# 29                    Ãndex de sobreenvelliment  (3)        52,7      50,2
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       263,0     280,2
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        68,4      93,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        18,2      20,7
# 33                    Nombre d'aturats registrats (5)         647     6.828
# 34      Renda familiar disponible per habitant (2017)        65,1      74,6
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 59   ----> Nombre d'aturats registrats (5)
# 59   ----> Renda familiar disponible per habitant (2017)
# 59   ----> Nombre d'aturats registrats (5)
# 59   ----> 65 i mes
# 59   ----> SuperfÃ­cie (km2)
# 59   ----> Densitat (hab/km2)
# 59   ----> Taxa natalitat / 1.000 hab.
# 59   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 59   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   58.508   151.976
# 1                                   SuperfÃ­cie (km2)      1,9       6,6
# 2                                  Densitat (hab/km2)   31.331    23.065
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   30.894    79.738
# 5                                               Homes   27.614    72.238
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     13,2      13,2
# 8                                               15-24      8,6       9,1
# 9                                               25-64     55,9      56,0
# 10                                           65 i mes     22,3      21,7
# ...
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 62   ----> Nombre d'aturats registrats (5)
# 62   ----> Renda familiar disponible per habitant (2017)
# 62   ----> Nombre d'aturats registrats (5)
# 62   ----> 65 i mes
# 62   ----> SuperfÃ­cie (km2)
# 62   ----> Densitat (hab/km2)
# 62   ----> Taxa natalitat / 1.000 hab.
# 62   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 62   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   22.457   151.976
# 1                                   SuperfÃ­cie (km2)      0,4       6,6
# 2                                  Densitat (hab/km2)   52.986    23.065
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   11.971    79.738
# 5                                               Homes   10.486    72.238
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     11,3      13,2
# 8                                               15-24      9,2       9,1
# 9                                               25-64     55,8      56,0
# 10                                           65 i mes     23,7      21,7
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     52,3      53,9
# 13                                    Resta Catalunya      6,6       6,9
# 14                                      Resta Espanya     16,6      17,7
# 15                                          Estranger     24,5      21,5
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     82,9      84,8
# 18                                         Estrangers     17,1      15,2
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN     Xina      Xina
# 21                                                NaN      601     2.129
# 22                                                NaN  ItÃ lia  Pakistan
# 23                                                NaN      391     1.710
# 24                                                NaN    PerÃº   ItÃ lia
# 25                                                NaN      285     1.675
# 26                    % Titulats superiors i CFGS (1)     28,0      24,4
# 27                        Taxa natalitat / 1.000 hab.      8,3       7,8
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     26,2      24,0
# 29                    Ãndex de sobreenvelliment  (3)     53,3      50,2
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    278,5     280,2
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)    106,1      93,8
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     21,5      20,7
# 33                    Nombre d'aturats registrats (5)      877     6.828
# 34      Renda familiar disponible per habitant (2017)     81,6      74,6
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 63   ----> Nombre d'aturats registrats (5)
# 63   ----> Renda familiar disponible per habitant (2017)
# 63   ----> Nombre d'aturats registrats (5)
# 63   ----> 65 i mes
# 63   ----> SuperfÃ­cie (km2)
# 63   ----> Densitat (hab/km2)
# 63   ----> Taxa natalitat / 1.000 hab.
# 63   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 63   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³      39.262   241.691
# 1                                   SuperfÃ­cie (km2)         0,7      10,4
# 2                                  Densitat (hab/km2)      53.011    23.270
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones      20.894   125.269
# 5                                               Homes      18.368   116.422
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        10,8      13,1
# 8                                               15-24         8,2       9,1
# 9                                               25-64        58,0      57,4
# 10                                           65 i mes        23,0      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        49,5      50,2
# 13                                    Resta Catalunya         7,3       6,8
# 14                                      Resta Espanya        15,4      17,3
# 15                                          Estranger        27,8      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        79,3      79,6
# 18                                         Estrangers        20,7      20,4
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN     ItÃ lia   ItÃ lia
# 21                                                NaN       1.035     5.674
# 22                                                NaN        Xina      Xina
# 23                                                NaN         761     4.476
# 24                                                NaN  VeneÃ§uela  Pakistan
# 25                                                NaN         427     4.181
# 26                    % Titulats superiors i CFGS (1)        32,8      28,4
# 27                        Taxa natalitat / 1.000 hab.         6,3       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        26,1      24,3
# 29                    Ãndex de sobreenvelliment  (3)        50,6      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       257,2     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)       109,2      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        23,7      21,8
# 33                    Nombre d'aturats registrats (5)       1.710    10.862
# 34      Renda familiar disponible per habitant (2017)        81,7      88,1
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 64   ----> Nombre d'aturats registrats (5)
# 64   ----> Renda familiar disponible per habitant (2017)
# 64   ----> Nombre d'aturats registrats (5)
# 64   ----> 65 i mes
# 64   ----> SuperfÃ­cie (km2)
# 64   ----> Densitat (hab/km2)
# 64   ----> Taxa natalitat / 1.000 hab.
# 64   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 64   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   27.069   241.691
# 1                                   SuperfÃ­cie (km2)      0,7      10,4
# 2                                  Densitat (hab/km2)   38.848    23.270
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   14.121   125.269
# 5                                               Homes   12.948   116.422
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     12,0      13,1
# 8                                               15-24      9,5       9,1
# 9                                               25-64     58,0      57,4
# 10                                           65 i mes     20,6      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     52,4      50,2
# 13                                    Resta Catalunya      6,9       6,8
# 14                                      Resta Espanya     17,4      17,3
# 15                                          Estranger     23,2      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     82,7      79,6
# 18                                         Estrangers     17,3      20,4
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN  ItÃ lia   ItÃ lia
# 21                                                NaN      635     5.674
# 22                                                NaN     Xina      Xina
# 23                                                NaN      503     4.476
# 24                                                NaN   Marroc  Pakistan
# 25                                                NaN      287     4.181
# 26                    % Titulats superiors i CFGS (1)     29,4      28,4
# 27                        Taxa natalitat / 1.000 hab.      6,7       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     23,1      24,3
# 29                    Ãndex de sobreenvelliment  (3)     46,8      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    279,0     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)    103,4      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     23,9      21,8
# 33                    Nombre d'aturats registrats (5)    1.169    10.862
# 34      Renda familiar disponible per habitant (2017)     83,6      88,1
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 65   ----> Nombre d'aturats registrats (5)
# 65   ----> Renda familiar disponible per habitant (2017)
# 65   ----> Nombre d'aturats registrats (5)
# 65   ----> 65 i mes
# 65   ----> SuperfÃ­cie (km2)
# 65   ----> Densitat (hab/km2)
# 65   ----> Taxa natalitat / 1.000 hab.
# 65   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 65   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   15.947   241.691
# 1                                   SuperfÃ­cie (km2)      1,1      10,4
# 2                                  Densitat (hab/km2)   14.212    23.270
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones    8.211   125.269
# 5                                               Homes    7.736   116.422
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     12,4      13,1
# 8                                               15-24      8,6       9,1
# 9                                               25-64     59,0      57,4
# 10                                           65 i mes     20,0      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     46,1      50,2
# 13                                    Resta Catalunya      6,8       6,8
# 14                                      Resta Espanya     17,3      17,3
# 15                                          Estranger     29,8      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     75,9      79,6
# 18                                         Estrangers     24,1      20,4
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN  ItÃ lia   ItÃ lia
# 21                                                NaN      651     5.674
# 22                                                NaN     Xina      Xina
# 23                                                NaN      348     4.476
# 24                                                NaN  FranÃ§a  Pakistan
# 25                                                NaN      217     4.181
# 26                    % Titulats superiors i CFGS (1)     37,1      28,4
# 27                        Taxa natalitat / 1.000 hab.      8,0       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     26,1      24,3
# 29                    Ãndex de sobreenvelliment  (3)     48,4      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    250,1     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)    104,9      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     22,4      21,8
# 33                    Nombre d'aturats registrats (5)      572    10.862
# 34      Renda familiar disponible per habitant (2017)    100,4      88,1
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 66   ----> Nombre d'aturats registrats (5)
# 66   ----> Renda familiar disponible per habitant (2017)
# 66   ----> Nombre d'aturats registrats (5)
# 66   ----> 65 i mes
# 66   ----> SuperfÃ­cie (km2)
# 66   ----> Densitat (hab/km2)
# 66   ----> Taxa natalitat / 1.000 hab.
# 66   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 66   ----> Ãndex de sobreenvelliment  (3)

# %%
for z in range(70,74):
    
    file = 'barri_'+str(z)+'.csv'
    path_file ="C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\" + file
    df=pd.read_csv (path_file , encoding = 'ISO-8859-1') 
    print(df)
    df_new =pd.DataFrame()
    
    for i in lista_param_correct:
        print (z,'  ---->', i)
        #print (df[df.iloc[:,0] == i].iloc[:,0])
        i_barrio = i +'_barrio'
        i_distrito = i +'_districte' 
        #i_BCN = i +'_BCN'
        columna1 =df.columns[1]
        columna2 =df.columns[2]
        df_new [i_barrio] = [df[df.iloc[:,0] == i][columna1].iloc[0]]
        df_new [i_distrito] = [df[df.iloc[:,0] == i][columna2].iloc[0]]
        #df_new [i_BCN] = [df[df.iloc[:,0] == i]['BARCELONA'].iloc[0]]
        df_new ['num_barrio']= z
    total_df = pd.concat([total_df, df_new])
# Out:
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³      25.501   241.691
# 1                                   SuperfÃ­cie (km2)         1,2      10,4
# 2                                  Densitat (hab/km2)      21.513    23.270
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones      12.280   125.269
# 5                                               Homes      13.221   116.422
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        14,4      13,1
# 8                                               15-24        10,7       9,1
# 9                                               25-64        58,5      57,4
# 10                                           65 i mes        16,4      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        39,4      50,2
# 13                                    Resta Catalunya         4,6       6,8
# 14                                      Resta Espanya        15,7      17,3
# 15                                          Estranger        40,2      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        65,0      79,6
# 18                                         Estrangers        35,0      20,4
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN    Pakistan   ItÃ lia
# 21                                                NaN       2.678     5.674
# 22                                                NaN  Marroc, el      Xina
# 23                                                NaN         659     4.476
# 24                                                NaN        Xina  Pakistan
# 25                                                NaN         447     4.181
# 26                    % Titulats superiors i CFGS (1)        12,8      28,4
# 27                        Taxa natalitat / 1.000 hab.         9,6       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        26,4      24,3
# 29                    Ãndex de sobreenvelliment  (3)        54,8      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       222,5     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        54,0      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        21,1      21,8
# 33                    Nombre d'aturats registrats (5)       1.392    10.862
# 34      Renda familiar disponible per habitant (2017)        60,4      88,1
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 70   ----> Nombre d'aturats registrats (5)
# 70   ----> Renda familiar disponible per habitant (2017)
# 70   ----> Nombre d'aturats registrats (5)
# 70   ----> 65 i mes
# 70   ----> SuperfÃ­cie (km2)
# 70   ----> Densitat (hab/km2)
# 70   ----> Taxa natalitat / 1.000 hab.
# 70   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 70   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019       BARRI DISTRICTE  \
# 0                                           PoblaciÃ³      21.523   241.691
# 1                                   SuperfÃ­cie (km2)         1,1      10,4
# 2                                  Densitat (hab/km2)      19.823    23.270
# 3                                  PoblaciÃ³ per sexe         NaN       NaN
# 4                                               Dones      11.180   125.269
# 5                                               Homes      10.343   116.422
# 6                           PoblaciÃ³ per edat (en %)         NaN       NaN
# 7                                                0-14        14,2      13,1
# 8                                               15-24         8,8       9,1
# 9                                               25-64        59,0      57,4
# 10                                           65 i mes        18,0      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)         NaN       NaN
# 12                                          Barcelona        53,8      50,2
# 13                                    Resta Catalunya         6,6       6,8
# 14                                      Resta Espanya        17,1      17,3
# 15                                          Estranger        22,5      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)         NaN       NaN
# 17                                          Espanyols        82,6      79,6
# 18                                         Estrangers        17,4      20,4
# 19               Principals nacionalitats estrangeres         NaN       NaN
# 20                                                NaN     ItÃ lia   ItÃ lia
# 21                                                NaN         471     5.674
# 22                                                NaN        Xina      Xina
# 23                                                NaN         245     4.476
# 24                                                NaN  Marroc, el  Pakistan
# 25                                                NaN         220     4.181
# 26                    % Titulats superiors i CFGS (1)        26,9      28,4
# 27                        Taxa natalitat / 1.000 hab.         9,0       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)        22,8      24,3
# 29                    Ãndex de sobreenvelliment  (3)        49,9      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)       291,4     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)        96,7      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)        21,6      21,8
# 33                    Nombre d'aturats registrats (5)         927    10.862
# 34      Renda familiar disponible per habitant (2017)       102,3      88,1
# 35                               Ãndex Barcelona=100         NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 71   ----> Nombre d'aturats registrats (5)
# 71   ----> Renda familiar disponible per habitant (2017)
# 71   ----> Nombre d'aturats registrats (5)
# 71   ----> 65 i mes
# 71   ----> SuperfÃ­cie (km2)
# 71   ----> Densitat (hab/km2)
# 71   ----> Taxa natalitat / 1.000 hab.
# 71   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 71   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   26.168   241.691
# 1                                   SuperfÃ­cie (km2)      0,7      10,4
# 2                                  Densitat (hab/km2)   35.652    23.270
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   13.945   125.269
# 5                                               Homes   12.223   116.422
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     11,8      13,1
# 8                                               15-24      8,8       9,1
# 9                                               25-64     54,0      57,4
# 10                                           65 i mes     25,4      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     51,8      50,2
# 13                                    Resta Catalunya      6,6       6,8
# 14                                      Resta Espanya     21,5      17,3
# 15                                          Estranger     20,1      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     85,4      79,6
# 18                                         Estrangers     14,6      20,4
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN     Xina   ItÃ lia
# 21                                                NaN      800     5.674
# 22                                                NaN  ItÃ lia      Xina
# 23                                                NaN      309     4.476
# 24                                                NaN    PerÃº  Pakistan
# 25                                                NaN      221     4.181
# 26                    % Titulats superiors i CFGS (1)     21,0      28,4
# 27                        Taxa natalitat / 1.000 hab.      7,1       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     24,9      24,3
# 29                    Ãndex de sobreenvelliment  (3)     57,6      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    282,3     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)     95,5      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     21,9      21,8
# 33                    Nombre d'aturats registrats (5)    1.290    10.862
# 34      Renda familiar disponible per habitant (2017)     67,4      88,1
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 72   ----> Nombre d'aturats registrats (5)
# 72   ----> Renda familiar disponible per habitant (2017)
# 72   ----> Nombre d'aturats registrats (5)
# 72   ----> 65 i mes
# 72   ----> SuperfÃ­cie (km2)
# 72   ----> Densitat (hab/km2)
# 72   ----> Taxa natalitat / 1.000 hab.
# 72   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 72   ----> Ãndex de sobreenvelliment  (3)
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   28.878   241.691
# 1                                   SuperfÃ­cie (km2)      1,1      10,4
# 2                                  Densitat (hab/km2)   25.619    23.270
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   15.171   125.269
# 5                                               Homes   13.707   116.422
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     11,8      13,1
# 8                                               15-24      9,1       9,1
# 9                                               25-64     52,8      57,4
# 10                                           65 i mes     26,4      20,4
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     48,3      50,2
# 13                                    Resta Catalunya      6,2       6,8
# 14                                      Resta Espanya     25,3      17,3
# 15                                          Estranger     20,2      25,8
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     85,3      79,6
# 18                                         Estrangers     14,7      20,4
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN     Xina   ItÃ lia
# 21                                                NaN      755     5.674
# 22                                                NaN  ItÃ lia      Xina
# 23                                                NaN      265     4.476
# 24                                                NaN    PerÃº  Pakistan
# 25                                                NaN      227     4.181
# 26                    % Titulats superiors i CFGS (1)     15,1      28,4
# 27                        Taxa natalitat / 1.000 hab.      6,1       7,7
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     21,8      24,3
# 29                    Ãndex de sobreenvelliment  (3)     55,1      51,8
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    301,3     271,6
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)     81,9      97,1
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     24,4      21,8
# 33                    Nombre d'aturats registrats (5)    1.461    10.862
# 34      Renda familiar disponible per habitant (2017)     57,0      88,1
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN
# 73   ----> Nombre d'aturats registrats (5)
# 73   ----> Renda familiar disponible per habitant (2017)
# 73   ----> Nombre d'aturats registrats (5)
# 73   ----> 65 i mes
# 73   ----> SuperfÃ­cie (km2)
# 73   ----> Densitat (hab/km2)
# 73   ----> Taxa natalitat / 1.000 hab.
# 73   ----> PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)
# 73   ----> Ãndex de sobreenvelliment  (3)

# %%
total_df.shape
# Out:
# (68, 17)

# %%
total_df.to_csv('total_extracted.csv')

# %%
barris_district[20:]
# Out:
#    num_barri                                      barri  num_districte
# 20        21                                  Les Corts              4
# 21        22                  La Maternidad y San Ramón              5
# 22        23                                  Pedralbes              5
# 23        24      Vallvidrera, el Tibidabo i les Planes              5
# 24        25                                     Sarriá              5
# 25        26                            Las Tres Torres              5
# 26        27                      Sant Gervasi-Bonanova              5
# 27        28                        Sant Gervasi-Galvan              6
# 28        29                       El Putxet i el Farró              6
# 29        30                 Vallcarca y los Penitentes              6
# 30        31                                    El Coll              6
# 31        32                                   La Salud              6
# 32        33                            Villa de Gracia              7
# 33        34            Camp d'en Grassot i Gràcia Nova              7
# 34        35                              Baix Guinardó              7
# 35        36                                   Can Baró              7
# 36        37                                El Guinardó              7
# 37        38                       La Font d'en Fargues              7
# 38        39                                 El Carmelo              7
# 39        40                               La Teixonera              7
# 40        41                   Sant Genís dels Agudells              7
# 41        42                                    Montbau              7
# 42        43                         El Valle de Hebrón              7
# 43        44                                   La Clota              8
# 44        45                                      Horta              8
# 45        46              Vilapicina y La Torre Llobeta              8
# 46        47                                      Porta              8
# 47        48                           Turó de la Peira              8
# 48        49                                Can Peguera              8
# 49        50                               La Guineueta              8
# 50        51                                  Canyelles              8
# 51        52                               Les Roquetes              8
# 52        53                                     Verdún              8
# 53        54                             La Prosperitat              8
# 54        55                           La Trinitat Nova              8
# 55        56                                 Torre Baró              8
# 56        57                           Ciudad Meridiana              9
# 57        58                                   Vallbona              9
# 58        59                          La Trinitat Vella              9
# 59        60                              Baró de Viver              9
# 60        61                             El Buen Pastor              9
# 61        62                                 San Andrés              9
# 62        63                                 La Sagrera              9
# 63        64                      Congrés i els Indians             10
# 64        65                                      Navas             10
# 65        66                 El Campo del Arpa del Clot             10
# 66        67                                    El Clot             10
# 67        68          El Parc i la Llacuna del Poblenou             10
# 68        69             La Villa Olímpica del Poblenou             10
# 69        70                               Pueblo Nuevo             10
# 70        71  Diagonal Mar i Front Marítim del Poblenou             10
# 71        72                      El Besós y el Maresme             10
# 72        73                    Provençals del Poblenou             10

# %%
total_df.groupby('num_barrio').sum().reset_index()

# %%
total_df.shape
# Out:
# (65, 17)

# %%
for z in range(17,74):
    file = 'barri_'+str(z)+'.csv'
    path_file ="C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\" + file
    df=pd.read_csv (path_file , encoding = 'ISO-8859-1') 
    df_new =pd.DataFrame()
    
    for i in lista_param_correct:
        print (z,'  ---->', i)
        #print (df[df.iloc[:,0] == i].iloc[:,0])
        i_barrio = i +'_barrio'
        i_distrito = i +'_districte' 
        i_BCN = i +'_BCN'
        df_new [i_barrio] = [df[df.iloc[:,0] == i]['BARRI'].iloc[0]]
        df_new [i_distrito] = [df[df.iloc[:,0] == i]['DISTRICTE'].iloc[0]]
        df_new [i_BCN] = [df[df.iloc[:,0] == i]['BARCELONA'].iloc[0]]
        df_new ['num_barrio']= z
    total_df = pd.concat([total_df, df_new])

# %%
total_df.columns
# Out:
# Index(['Nombre d'aturats registrats (5)_barrio',
#        'Nombre d'aturats registrats (5)_districte', 'num_barrio',
#        'Renda familiar disponible per habitant (2017)_barrio',
#        'Renda familiar disponible per habitant (2017)_districte',
#        '65 i mes_barrio', '65 i mes_districte', 'SuperfÃ­cie (km2)_barrio',
#        'SuperfÃ­cie (km2)_districte', 'Densitat (hab/km2)_barrio',
#        'Densitat (hab/km2)_districte', 'Taxa natalitat / 1.000 hab._barrio',
#        'Taxa natalitat / 1.000 hab._districte',
#        'PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio',
#        'PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_districte',
#        'Ãndex de sobreenvelliment  (3)_barrio',
#        'Ãndex de sobreenvelliment  (3)_districte'],
#       dtype='object')

# %%
total_df[['num_barrio','PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio']]
total_df ['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'] =  [ x.split(' ')[0] for x in list(total_df ['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'])]
total_df ['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'] =  [ to_num(x) for x in list(total_df ['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'])]

# %%
total_df[['num_barrio','PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio']].to_csv('prova.csv')

# %%
print (max(list(total_df['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'])))
print (min(list(total_df['PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio'])))
# Out:
# 33.6
# 13.9

# %%
lista_generar = ['num_barrio','Renda familiar disponible per habitant (2017)_barrio']
def generar_csv (columns_dos):
    nombre = columns_dos[1] +'.csv'
    total_df.loc[lista_generar].to_csv (nombre)

generar_csv (lista_generar)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\1383895643.py in <module>
#       4     total_df.loc[lista_generar].to_csv (nombre)
#       5
# ----> 6 generar_csv (lista_generar)
#
# ~\AppData\Local\Temp\ipykernel_29680\1383895643.py in generar_csv(columns_dos)
#       2 def generar_csv (columns_dos):
#       3     nombre = columns_dos[1] +'.csv'
# ----> 4     total_df.loc[lista_generar].to_csv (nombre)
#       5
#       6 generar_csv (lista_generar)
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['num_barrio', 'Renda familiar disponible per habitant (2017)_barrio'], dtype='object')] are in the [index]"

# %%
graficas =["Nombre d'aturats registrats (5)_barrio",
       'Renda familiar disponible per habitant (2017)_barrio',
       '65 i mes_barrio', 
        'SuperfÃ­cie (km2)_barrio',
         'Densitat (hab/km2)_barrio',
          'Taxa natalitat / 1.000 hab._barrio',
       'PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)_barrio',
       'Ãndex de sobreenvelliment  (3)_barrio'
       ]

# %%
 generar_csv(['num_barrio','Ãndex de sobreenvelliment  (3)_barrio'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\756448420.py in <module>
# ----> 1 generar_csv([['num_barrio','Ãndex de sobreenvelliment  (3)_barrio']])
#
# ~\AppData\Local\Temp\ipykernel_29680\2792272512.py in generar_csv(columns_dos)
#       1 lista_generar = ['num_barrio','Renda familiar disponible per habitant (2017)_barrio']
#       2 def generar_csv (columns_dos):
# ----> 3     nombre = columns_dos[1] +'.csv'
#       4     total_df.loc[lista_generar].to_csv
#
# IndexError: list index out of range

# %%
for i in graficas:
    generar_csv(['num_barrio', i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\955328486.py in <module>
#       1 for i in graficas:
# ----> 2     generar_csv(['num_barrio', i])
#
# ~\AppData\Local\Temp\ipykernel_29680\2792272512.py in generar_csv(columns_dos)
#       2 def generar_csv (columns_dos):
#       3     nombre = columns_dos[1] +'.csv'
# ----> 4     total_df.loc[lista_generar].to_csv
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# c:\Users\march\anaconda3\envs\EDA_i_ML_37\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['num_barrio', 'Renda familiar disponible per habitant (2017)_barrio'], dtype='object')] are in the [index]"

# %%
list(df['INDICADORS SOCIOECONÃMICS 2019'])
# Out:
# ['PoblaciÃ³',
#  'SuperfÃ\xadcie (km2)',
#  'Densitat (hab/km2)',
#  'PoblaciÃ³ per sexe',
#  'Dones',
#  'Homes',
#  'PoblaciÃ³ per edat (en %)',
#  '0-14',
#  '15-24',
#  '25-64',
#  '65 i mes',
#  'PoblaciÃ³ per lloc de naixement (en %)',
#  'Barcelona',
#  'Resta Catalunya',
#  'Resta Espanya',
#  'Estranger',
#  'PoblaciÃ³ per nacionalitat (en %)',
#  'Espanyols',
#  'Estrangers',
#  'Principals nacionalitats estrangeres',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '% Titulats superiors i CFGS (1)',
#  'Taxa natalitat / 1.000 hab.',
#  'PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)',
#  'Ã\x8dndex de sobreenvelliment  (3)',
#  'Turismes (persones fÃ\xadsiques) / 1.000 hab (4)',
#  'Motos (persones fÃ\xadsiques) / 1.000 hab (4)',
#  'Ciclomotors (persones fÃ\xadsiques) / 1.000 hab (4)',
#  "Nombre d'aturats registrats (5)",
#  'Renda familiar disponible per habitant (2017)',
#  'Ã\x8dndex Barcelona=100']

# %%
df
# Out:
#                       INDICADORS SOCIOECONÃMICS 2019    BARRI DISTRICTE  \
# 0                                           PoblaciÃ³   43.228   270.694
# 1                                   SuperfÃ­cie (km2)      1,2       7,5
# 2                                  Densitat (hab/km2)   35.189    36.265
# 3                                  PoblaciÃ³ per sexe      NaN       NaN
# 4                                               Dones   22.910   144.056
# 5                                               Homes   20.318   126.638
# 6                           PoblaciÃ³ per edat (en %)      NaN       NaN
# 7                                                0-14     10,2      10,5
# 8                                               15-24      9,0       8,8
# 9                                               25-64     59,9      58,8
# 10                                           65 i mes     20,8      21,9
# 11             PoblaciÃ³ per lloc de naixement (en %)      NaN       NaN
# 12                                          Barcelona     46,4      47,1
# 13                                    Resta Catalunya      8,9       8,4
# 14                                      Resta Espanya     12,6      13,9
# 15                                          Estranger     32,1      30,7
# 16                  PoblaciÃ³ per nacionalitat (en %)      NaN       NaN
# 17                                          Espanyols     74,4      75,6
# 18                                         Estrangers     25,6      24,4
# 19               Principals nacionalitats estrangeres      NaN       NaN
# 20                                                NaN  ItÃ lia   ItÃ lia
# 21                                                NaN    1.596     9.559
# 22                                                NaN  FranÃ§a      Xina
# 23                                                NaN      807     6.119
# 24                                                NaN     Xina   FranÃ§a
# 25                                                NaN      717     4.258
# 26                    % Titulats superiors i CFGS (1)     49,7      44,5
# 27                        Taxa natalitat / 1.000 hab.      7,2       7,2
# 28  PoblaciÃ³ de mÃ©s de 65 anys que viu sola (%) (2)     29,0      27,4
# 29                    Ãndex de sobreenvelliment  (3)     54,4      53,5
# 30      Turismes (persones fÃ­siques) / 1.000 hab (4)    232,8     245,4
# 31         Motos (persones fÃ­siques) / 1.000 hab (4)    141,9     126,7
# 32   Ciclomotors (persones fÃ­siques) / 1.000 hab (4)     24,7      24,2
# 33                    Nombre d'aturats registrats (5)    1.345     9.326
# 34      Renda familiar disponible per habitant (2017)    137,2     122,4
# 35                               Ãndex Barcelona=100      NaN       NaN
#
#     BARCELONA
# 0   1.666.530
# 1       101,4
# 2      16.443
# 3         NaN
# 4     874.423
# 5     792.107
# 6         NaN
# 7        12,3
# 8         9,4
# 9        57,2
# 10       21,1
# 11        NaN
# 12       49,3
# 13        7,2
# 14       15,7
# 15       27,8
# 16        NaN
# 17       78,3
# 18       21,7
# 19        NaN
# 20    ItÃ lia
# 21     39.863
# 22   Pakistan
# 23     22.749
# 24       Xina
# 25     22.477
# 26       33,4
# 27        7,7
# 28       25,7
# 29       53,4
# 30      263,5
# 31      119,8
# 32       25,0
# 33     69.047
# 34      100,0
# 35        NaN

# %%
df=pd.read_csv('C:\\Users\\march\\000 Treball Ju`yter 000\\Hackathons\\Hackathon_Jornada_Talent_Digita_Oct_2022l\\CSV\\1.csv', encoding = 'ISO-8859-1')

# %%
df [df.iloc[:,0] == 'Principals nacionalitats estrangeres']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\317845856.py in <module>
# ----> 1 df [df.iloc[:,0] == 'Principals nacionalitats estrangeres']
#
# NameError: name 'df' is not defined

# %%
df_new =pd.DataFrame()
for i in lista_param:
    #print (df[df.iloc[:,0] == i].iloc[:,0])
    i_barrio = i +'_barrio'
    i_distrito = i +'_districte' 
    i_BCN = i +'_BCN'
    df_new [i_barrio] = [df[df.iloc[:,0] == i]['Unnamed: 1'].iloc[0]]
    df_new [i_distrito] = [df[df.iloc[:,0] == i]['Unnamed: 2'].iloc[0]]
    df_new [i_BCN] = [df[df.iloc[:,0] == i]['Unnamed: 3'].iloc[0]]
    df ['num_barrio']=

# %%
df_new.to_json('datos_extraidos.json')

# %%
df_new.to_csv('datos_extraidos.csv')

# %%
df_new
# Out:
#   Nombre d'aturats registrats (5)_barrio  \
# 0                                  3.074
#
#   Nombre d'aturats registrats (5)_districte  \
# 0                                     6.290
#
#   Nombre d'aturats registrats (5)_BCN  \
# 0                              69.047
#
#   Renda familiar disponible per habitant (2017)_barrio  \
# 0                                               71,2
#
#   Renda familiar disponible per habitant (2017)_districte  \
# 0                                               84,3
#
#   Renda familiar disponible per habitant (2017)_BCN 65 i mes_barrio  \
# 0                                             100,0            11,3
#
#   65 i mes_districte 65 i mes_BCN Superfície (km2)_barrio  ...  \
# 0               12,3         21,1                     1,1  ...
#
#   Densitat (hab/km2)_BCN Taxa natalitat / 1.000 hab._barrio  \
# 0                 16.443                                9,1
#
#   Taxa natalitat / 1.000 hab._districte Taxa natalitat / 1.000 hab._BCN  \
# 0                                   7,6                             7,7
#
#   Població de més de 65 anys que viu sola (%) (2)_barrio  \
# 0                                               31,9
#
#   Població de més de 65 anys que viu sola (%) (2)_districte  \
# 0                                               32,2
#
#   Població de més de 65 anys que viu sola (%) (2)_BCN  \
# 0                                               25,7
#
#   Índex de sobreenvelliment  (3)_barrio  \
# 0                                  50,7
#
#   Índex de sobreenvelliment  (3)_districte Índex de sobreenvelliment  (3)_BCN
# 0                                     52,6                               53,4
#
# [1 rows x 24 columns]

# %%
df[df.iloc[:,0] == 'Principals nacionalitats estrangeres']['Unnamed: 1'].iloc[0]
# Out:
# nan

# %%
df[df.iloc[:,0] == 'Principals nacionalitats estrangeres']
# Out:
#                Districte de Ciutat Vella Unnamed: 1 Unnamed: 2 Unnamed: 3
# 21  Principals nacionalitats estrangeres        NaN        NaN        NaN

# %%
aa.iloc[0,0]
aa.index = aa[aa.columns[0]]
aa.loc['Població','Unnamed: 1']
# Out:
# '48.263'

# %%
csv_lst = pd.read_csv('https://opendata-ajuntament.barcelona.cat/data/dataset/ef40b336-1b27-4ecf-9fc8-63af0347a7c0/resource/ed515bb8-502b-4dff-96dc-769f72767919/download/2019_divter.csv')

# %%
to_num('123,4')
# Out:
# 123.4

# %% [markdown]
# # Previ

# %%
df = tabula.read_pdf(path, pages = all)
print(df[0])

# %%
def barrio_num (text):
    '''funtion to extract a number and name of districts/neightbourhoods of BCN from a text:
            INPUT: a text
            OUTPUT: 2 list (one of number codes and the other one of names)
    '''
    section1 = text.split(')')
    name, number = [] , []
    for i in section1:
        if i!='':
            section2 = i.split('(')
            name.append (section2[0].strip().strip(',\xa0').strip('y\xa0'))
            new_num = section2[1].strip()
            if new_num!='*':
                number.append (new_num)
    return  number, name

# %%
super_llista = ["El Raval (1), Barrio Gótico (2), La Barceloneta (3) y San Pedro, Santa Catalina y la Ribera (4)",            
           'El Fort Pienc (5), Sagrada Familia (6), La Derecha del Ensanche (7), La Antigua Izquierda del Ensanche (8), La Nueva Izquierda del Ensanche (9) y San Antonio (10)',
            'Pueblo Seco (11), La Marina del Prat Vermell (12), La Marina de Port (13), La Font de la Guatlla (14), Hostafrancs (15), La Bordeta (16), Sants-Badal (17), Sants (18), Zona Franca (*) y Montjuïc (*)',
            'Les Corts (19), La Maternidad y San Ramón (20) y Pedralbes (21)',
            'Vallvidrera, el Tibidabo i les Planes (22), Sarriá (23), Las Tres Torres (24), Sant Gervasi-Bonanova (25), Sant Gervasi-Galvany (26) y El Putxet i el Farró (27)',
            "Vallcarca y los Penitentes (28), El Coll (29), La Salud (30), Villa de Gracia (31) y Camp d'en Grassot i Gràcia Nova (32)",
            "Baix Guinardó (33), Can Baró (34), El Guinardó (35), La Font d'en Fargues (36), El Carmelo (37), La Teixonera (38), Sant Genís dels Agudells (39), Montbau (40), El Valle de Hebrón (41), La Clota (42) y Horta (43)",
            "Vilapicina y La Torre Llobeta (44), Porta (45), Turó de la Peira (46), Can Peguera (47), La Guineueta (48), Canyelles (49), Les Roquetes (50), Verdún (51), La Prosperitat (52), La Trinitat Nova (53), Torre Baró (54), Ciudad Meridiana (55) y Vallbona (56)",
            "La Trinitat Vella (57), Baró de Viver (58), El Buen Pastor (59), San Andrés (60), La Sagrera (61), Congrés i els Indians (62) y Navas (63)",
            "El Campo del Arpa del Clot (64), El Clot (65), El Parc i la Llacuna del Poblenou (66), La Villa Olímpica del Poblenou (67), Pueblo Nuevo (68), Diagonal Mar i Front Marítim del Poblenou (69), El Besós y el Maresme (70), Provençals del Poblenou (71), San Martín de Provensals (72) y La Verneda y la Paz (73)"
            ]

# %%
#extract name of neightborhoods and its codes, also the districts codes
barrio =[]
num_barrio = []
districts=[]
j=1
for i in super_llista:
            num_list, barrio_list = barrio_num(i)
            num_barrio = num_barrio + num_list
            barrio = barrio + barrio_list
            new_dist =[]
            for z in range(len(num_list)):
                new_dist.append(j)
            districts = districts + new_dist
            j+=1

# %%
barris_district = pd.DataFrame (zip( num_barrio, barrio, districts), columns = ['num_barri', 'barri', 'num_districte'])

# %%
barris_district
# Out:
#    num_barri                                      barri  num_districte
# 0          1                                   El Raval              1
# 1          2                              Barrio Gótico              1
# 2          3                             La Barceloneta              1
# 3          4      San Pedro, Santa Catalina y la Ribera              1
# 4          5                              El Fort Pienc              2
# ..       ...                                        ...            ...
# 68        69             La Villa Olímpica del Poblenou             10
# 69        70                               Pueblo Nuevo             10
# 70        71  Diagonal Mar i Front Marítim del Poblenou             10
# 71        72                      El Besós y el Maresme             10
# 72        73                    Provençals del Poblenou             10
#
# [73 rows x 3 columns]

# %%
barris_district.num_barri = [str(int(x)) for x in barris_district.num_barri] #to treat as ctegories
barris_district.num_districte = [str(int(x)) for x in barris_district.num_districte]

# %%
barris_district.to_excel('barris_districtes.xlsx', index=False)
barris_district.to_csv('barris_districtes.csv', index=False)

# %%
def collect_all_data (list_webs):
    '''Funtion to donlowd csv files from a list of direct download
            INPUT:  list of direct download of the csv file 
            OUTPUT: one big dataframe containing all downloaded csv
    '''
    total_df =pd.DataFrame()
    for i in list_webs:
        new_df = pd.read_csv (i)
        total_df = pd.concat ([total_df, new_df])
    return total_df

# %%
webs_padro_viu_sola_edat_2007_2022  = [   'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/f14f5367-fb27-4602-a0a6-fe69210ad035/download/2007_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/c173c31e-f97a-44e4-b329-eaf07b8ebfde/download/2008_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/591d3333-22a4-4ed9-a116-a4fd44886786/download/2009_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/b3c841b8-8091-4f71-993c-fb887baa85e4/download/2010_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/2c512878-3b70-43c8-bc20-7a9f743fccb2/download/2011_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/de1ad06a-e78b-4494-b585-5ba72cd0a41a/download/2012_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/77911dcc-fda0-48a0-b814-5687bbaa4141/download/2013_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/d2fb74dd-5735-4f0e-bfa8-e56bd1da0bdd/download/2014_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/0a22c6fb-f065-41bc-9d09-1bbe90ece947/download/2015_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/9c9f3104-d52c-48ff-8e30-8318948f25ef/download/2016_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/05061546-5ef5-4f97-b9f2-c0f4488e3db7/download/2017_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/9fffca9f-330b-4ab8-90d3-06d53947f577/download/2018_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/a948cb3c-d8c7-4abf-93f1-5a5446c783e9/download/2019_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/7af6e2e8-b616-43ce-bb76-f45e337776db/download/2020_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/af99261c-6ba3-4c19-b9f7-3e3965bedfe0/download/2021_padro_viu_sola_edat_quinquennal.csv',
                'https://opendata-ajuntament.barcelona.cat/data/dataset/456d698a-2bb7-4c98-ad66-106854b4ebc2/resource/b30bc413-fbbb-44ba-9550-1aebfddd0889/download/2022_padro_viu_sola_edat_quinquennal.csv'
            ]

# %%
padro_viu_sola_edat_2007_2022 = collect_all_data (webs_padro_viu_sola_edat_2007_2022)

# %%
padro_viu_sola_edat_2007_2022.shape
# Out:
# (38444, 8)

# %%
padro_viu_sola_edat_2007_2022.Nombre = [str(x) for x in padro_viu_sola_edat_2007_2022.Nombre]

# %%
padro_viu_sola_edat_2007_2022.to_csv('padro_viu_sola_edat_2007_2022.csv', index=False)

# %%
webs_taxa_inmigracio_2009_2021  = [     'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/6fcb197f-d012-43aa-8136-7844f510e024/download/2009_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/b8d456e2-d44b-40f0-aea2-1507056e3b38/download/2010_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/e86f370a-1de1-4ee9-9147-47a25b884fd3/download/2011_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/2357ae81-e957-49cb-9538-8ca0b1fdcc73/download/2012_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/02965fae-b8b7-43e8-9d8f-00237266f355/download/2013_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/bcf83110-8492-4000-b1dc-8668c6abd1e8/download/2014_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/67594114-2dda-4b1d-8ad8-840a084775ef/download/2015_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/66be6027-bd54-4039-be15-9e5faa616ce2/download/2016_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/d0fc6cac-a252-4cb1-9661-b1a9c38d05d5/download/2017_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/bf82f3fc-5a9a-48fd-8e95-75ed1b5aa7ea/download/2018_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/04ceda77-ceb5-4ae7-ad64-20a4cb4f94f0/download/2019_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/43539e03-0d1c-4355-b144-65b110918d8c/download/2020_taxa_immigracio.csv',
                                        'https://opendata-ajuntament.barcelona.cat/data/dataset/9e7d4905-914a-4ee6-9992-9bdecf1c018d/resource/fee0ae5c-a5d9-4e9a-8535-64bfea96d8e6/download/2021_taxa_immigracio.csv',
]

# %%
taxa_inmigracio_2009_2021 = collect_all_data (webs_taxa_inmigracio_2009_2021)

# %%
taxa_inmigracio_2009_2021.reset_index(inplace=True)
taxa_inmigracio_2009_2021.drop('index',axis=1, inplace= True)

# %%
taxa_inmigracio_2009_2021.isnull().sum()
# Out:
# Any                 0
# Codi_Districte     73
# Nom_Districte      73
# Codi_Barri         73
# Nom_Barri          73
# Taxa_mil_hab        0
# Codi_districte    876
# Nom_districte     876
# Codi_barri        876
# Nom_barri         876
# Nombre            657
# dtype: int64

# %%
nova_columna_tax, nova_columna_Codi_D, nova_columna_Nom_D, nova_columna_Codi_B, nova_columna_Nom_B  = [], [], [], [], []
for i in range(len (taxa_inmigracio_2009_2021)):
    if taxa_inmigracio_2009_2021.isnull().iloc[i].Codi_Districte == True:
        nova_columna_Codi_D.append (taxa_inmigracio_2009_2021.iloc[i].Codi_districte)
        nova_columna_Nom_D.append (taxa_inmigracio_2009_2021.iloc[i].Nom_districte)
        nova_columna_Codi_B.append (taxa_inmigracio_2009_2021.iloc[i].Codi_barri)
        nova_columna_Nom_B.append (taxa_inmigracio_2009_2021.iloc[i].Nom_barri)
    else:
        nova_columna_Codi_D.append (taxa_inmigracio_2009_2021.iloc[i].Codi_Districte)
        nova_columna_Nom_D.append (taxa_inmigracio_2009_2021.iloc[i].Nom_Districte)
        nova_columna_Codi_B.append (taxa_inmigracio_2009_2021.iloc[i].Codi_Barri)
        nova_columna_Nom_B.append (taxa_inmigracio_2009_2021.iloc[i].Nom_Barri)
            
    if taxa_inmigracio_2009_2021.iloc[i].Taxa_mil_hab == 'Taxa per mil habitants':
        nova_columna_tax.append(taxa_inmigracio_2009_2021.iloc[i].Nombre)
    else:
        nova_columna_tax.append(taxa_inmigracio_2009_2021.iloc[i].Taxa_mil_hab)

taxa_inmigracio_2009_2021.Taxa_mil_hab = nova_columna_tax
taxa_inmigracio_2009_2021.Codi_Districte = nova_columna_Codi_D
taxa_inmigracio_2009_2021.Nom_Districte = nova_columna_Nom_D
taxa_inmigracio_2009_2021.Codi_Barri = nova_columna_Codi_B
taxa_inmigracio_2009_2021.Nom_Barri = nova_columna_Nom_B

# %%
taxa_inmigracio_2009_2021.drop (['Nom_barri', 'Codi_barri', 'Nom_districte', 'Codi_districte', 'Nombre'], axis = 1, inplace= True)

# %%
taxa_inmigracio_2009_2021.isnull().sum()
# Out:
# Any               0
# Codi_Districte    0
# Nom_Districte     0
# Codi_Barri        0
# Nom_Barri         0
# Taxa_mil_hab      0
# dtype: int64

# %%
taxa_inmigracio_2009_2021.Codi_Districte = [str(int(x)) for x in taxa_inmigracio_2009_2021.Codi_Districte] #to treat as ctegories

# %%
taxa_inmigracio_2009_2021.Codi_Barri = [str(int(x)) for x in taxa_inmigracio_2009_2021.Codi_Barri] #to treat as ctegories

# %%
taxa_inmigracio_2009_2021.to_csv('taxa_inmigracio_2009_2021.csv', index=False)

# %%
taxa_inmigracio_2009_2021
# Out:
#       Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2009             1.0  Ciutat Vella         1.0
# 1    2009             1.0  Ciutat Vella         2.0
# 2    2009             1.0  Ciutat Vella         3.0
# 3    2009             1.0  Ciutat Vella         4.0
# 4    2009             2.0      Eixample         5.0
# ..    ...             ...           ...         ...
# 944  2021            10.0    Sant Martí        69.0
# 945  2021            10.0    Sant Martí        70.0
# 946  2021            10.0    Sant Martí        71.0
# 947  2021            10.0    Sant Martí        72.0
# 948  2021            10.0    Sant Martí        73.0
#
#                                         Nom_Barri  Taxa_mil_hab
# 0                                        el Raval         117.2
# 1                                  el Barri Gòtic          99.6
# 2                                  la Barceloneta          83.9
# 3           Sant Pere, Santa Caterina i la Ribera          92.3
# 4                                   el Fort Pienc          68.3
# ..                                            ...           ...
# 944  Diagonal Mar i el Front Marítim del Poblenou          56.5
# 945                         el Besòs i el Maresme          95.6
# 946                       Provençals del Poblenou          45.7
# 947                      Sant Martí de Provençals          41.6
# 948                           la Verneda i la Pau          43.3
#
# [949 rows x 6 columns]

# %%
def plot_bar (df, year, group='' ):
    df_new = df[df.Any == year].copy()
    if group !='' and group in df.columns:
        df_new.group_by(group)

# %%
taxa_inmigracio_2009_2021[taxa_inmigracio_2009_2021.Any == 2021][['Any', 'Codi_Barri', 'Nom_Barri', 'Taxa_mil_hab']].to_excel('Inmigracio_2021.xlsx', index=False)

# %%
padro_viu_sola_edat_2007_2022.Nombre = [int(x) for x in padro_viu_sola_edat_2007_2022.Nombre]

# %%
padro_viu_sola_edat_2007_2022[padro_viu_sola_edat_2007_2022.Any == 2022].groupby('Codi_Barri').sum()['Nombre']
# Out:
# Codi_Barri
# 1     6109
# 2     2634
# 3     3000
# 4     4236
# 5     4019
#       ...
# 69    1580
# 70    2319
# 71    2233
# 72    3090
# 73    3162
# Name: Nombre, Length: 73, dtype: int64

# %%
padro_viu_sola_edat_2007_2022[(padro_viu_sola_edat_2007_2022.Any == 2022)& 
                                    ((padro_viu_sola_edat_2007_2022.Edat_quinquennal == '80-84 anys')|
                                    (padro_viu_sola_edat_2007_2022.Edat_quinquennal == '85-90 anys')|
                                    (padro_viu_sola_edat_2007_2022.Edat_quinquennal == '75-89 anys')|
                                    (padro_viu_sola_edat_2007_2022.Edat_quinquennal == '90-94 anys')|
                                    (padro_viu_sola_edat_2007_2022.Edat_quinquennal == '95-99 anys')|
                                    (padro_viu_sola_edat_2007_2022.Edat_quinquennal == '100 anys i més'))
                                    ]

# %%
def select_older75_year(df, year):
    new_df = df[(df.Any == year)& 
                ((df.Edat_quinquennal == '80-84 anys')|
                (df.Edat_quinquennal == '85-90 anys')|
                (df.Edat_quinquennal == '75-89 anys')|
                (df.Edat_quinquennal == '90-94 anys')|
                (df.Edat_quinquennal == '95-99 anys')|
                (df.Edat_quinquennal == '100 anys i més'))
                ]
    return new_df

# %%
select_older75_year(padro_viu_sola_edat_2007_2022,2022).groupby('Codi_Barri').sum()
# Out:
#               Any  Codi_Districte  Nombre
# Codi_Barri
# 1           16176               8     430
# 2           16176               8     167
# 3           16176               8     246
# 4           16176               8     267
# 5           16176              16     522
# ...           ...             ...     ...
# 69          16176              80     119
# 70          16176              80     338
# 71          16176              80     277
# 72          16176              80     517
# 73          16176              80     513
#
# [73 rows x 3 columns]

# %%
dist_old_alone_2007_2022 = pd.DataFrame()
for year in range (2007, 2023):
    df_new = pd.DataFrame (select_older75_year(padro_viu_sola_edat_2007_2022, year).groupby('Codi_Districte').Nombre.sum()).reset_index()
    df_new['Any'] = year
    dist_old_alone_2007_2022 = pd.concat([dist_old_alone_2007_2022, df_new])
